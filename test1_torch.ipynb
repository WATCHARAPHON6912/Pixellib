# %%
import pixellib
from pixellib.torchbackend.instance import instanceSegmentation

ins = instanceSegmentation()
ins.load_model("pointrend_resnet50.pkl")
ins.segmentImage("cycle.jpg", show_bboxes=False, output_image_name="output_image.jpg")
# Out:
# The checkpoint state_dict contains keys that are not used by the model:
#   proposal_generator.anchor_generator.cell_anchors.{0, 1, 2, 3, 4}
# ({'boxes': array([[ 312,  197,  424,  504],
#          [ 395,  120,  464,  173],
#          [ 184,  124,  209,  203],
#          [ 448,  142,  551,  220],
#          [ 721,  151,  884,  283],
#          [ 536,  163,  714,  313],
#          [ 340,  364,  399,  534],
#          [ 955,  123,  982,  185],
#          [ 916,  185,  999,  283],
#          [ 226,   96,  240,  135],
#          [  91,  201,  130,  318],
#          [ 537,  137,  615,  190],
#          [ 755,  102,  773,  145],
#          [ 282,   97,  318,  129],
#          [ 694,  146,  739,  207],
#          [ 981,  209, 1000,  296],
#          [ 308,  149,  346,  222],
#          [ 113,  218,  131,  270],
#          [ 489,  100,  549,  146],
#          [ 695,  144,  815,  211],
#          [ 628,  123,  702,  166],
#          [ 715,  149,  752,  221],
#          [ 651,  145,  744,  209],
#          [ 847,  126,  864,  173],
#          [ 447,   96,  457,  126],
#          [ 320,  155,  337,  176],
#          [ 157,    3,  180,   85],
#          [ 120,  262,  138,  295],
#          [ 312,  165,  347,  229],
#          [ 562,   97,  576,  132],
#          [ 773,  138,  876,  198],
#          [ 785,  138,  863,  177],
#          [ 324,  329,  413,  476]], dtype=int64),
#   'class_ids': array([ 0,  2,  0,  2,  2,  2,  1,  0,  2,  0,  0,  2,  0,  2,  2,  2,  0,
#          26,  2,  2,  2,  2,  2,  0,  0, 24,  9, 26,  3,  0,  2,  2,  1],
#         dtype=int64),
#   'class_names': ['person',
#    'car',
#    'person',
#    'car',
#    'car',
#    'car',
#    'bicycle',
#    'person',
#    'car',
#    'person',
#    'person',
#    'car',
#    'person',
#    'car',
#    'car',
#    'car',
#    'person',
#    'handbag',
#    'car',
#    'car',
#    'car',
#    'car',
#    'car',
#    'person',
#    'person',
#    'backpack',
#    'traffic light',
#    'handbag',
#    'motorcycle',
#    'person',
#    'car',
#    'car',
#    'bicycle'],
#   'object_counts': Counter({'person': 10,
#            'car': 16,
#            'bicycle': 2,
#            'handbag': 2,
#            'backpack': 1,
#            'traffic light': 1,
#            'motorcycle': 1}),
#   'scores': tensor([99, 99, 99, 97, 97, 97, 97, 96, 96, 96, 95, 93, 90, 89, 89, 84, 83, 79,
#           78, 78, 76, 74, 71, 70, 68, 66, 63, 61, 59, 59, 58, 55, 51]),
#   'masks': array([[[False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False],
#           ...,
#           [False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False]],
#
#          [[False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False],
#           ...,
#           [False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False]],
#
#          [[False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False],
#           ...,
#           [False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False]],
#
#          ...,
#
#          [[False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False],
#           ...,
#           [False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False]],
#
#          [[False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False],
#           ...,
#           [False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False]],
#
#          [[False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False],
#           ...,
#           [False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False],
#           [False, False, False, ..., False, False, False]]]),
#   'extracted_objects': []},
#  array([[[  1,   1,   1],
#          [  1,   1,   1],
#          [  1,   1,   1],
#          ...,
#          [ 41,  99,  74],
#          [ 46, 104,  79],
#          [ 44, 102,  77]],
#
#         [[  1,   1,   1],
#          [  1,   1,   1],
#          [  1,   1,   1],
#          ...,
#          [ 49, 105,  82],
#          [ 40,  96,  73],
#          [ 33,  89,  66]],
#
#         [[  1,   1,   1],
#          [  1,   1,   1],
#          [  1,   1,   1],
#          ...,
#          [ 64, 117,  97],
#          [ 53, 106,  86],
#          [ 50, 103,  83]],
#
#         ...,
#
#         [[  1,   1,   1],
#          [  1,   1,   1],
#          [  1,   1,   1],
#          ...,
#          [ 87,  90,  94],
#          [ 89,  92,  96],
#          [ 84,  87,  91]],
#
#         [[  1,   1,   1],
#          [  1,   1,   1],
#          [  1,   1,   1],
#          ...,
#          [ 88,  91,  95],
#          [ 87,  90,  94],
#          [ 85,  88,  92]],
#
#         [[  1,   1,   1],
#          [  1,   1,   1],
#          [  1,   1,   1],
#          ...,
#          [ 89,  92,  96],
#          [ 87,  90,  94],
#          [ 87,  90,  94]]], dtype=uint8))
