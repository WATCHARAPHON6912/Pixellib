# %%
import cv2
import pixellib
import matplotlib.pyplot as plt
from pixellib.instance import instance_segmentation
segment_image = instance_segmentation()
segment_image.load_model("mask_rcnn_coco.h5")
# Out:
# WARNING:tensorflow:From c:\anaconda3\envs\py38_tf_gpu\lib\site-packages\tensorflow\python\util\deprecation.py:605: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead

# %%
frame=cv2.imread("cycle.jpg")
result=segment_image.segmentFrame(frame,show_bboxes=True)
image=result[1]
# print(result[0])
plt.imshow(image)

# cv2.imshow('Image Segmentation',image)
# cv2.waitKey(0)
